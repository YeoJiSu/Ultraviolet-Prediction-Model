# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # 데이터 셋 가져오기
# * train 데이터는 df_all 에 저장
# * test 데이터는 df 에 저장

# %%
# train 데이터 가져오기
df_all = pd.DataFrame()
year = 2020
for k in range(2):
  forders = os.listdir('/content/drive/MyDrive/Meta Data/'+str(year)+'/')
  for i in range(0,len(forders)):
      if forders[i].split('.')[1] == 'csv':
          file = '/content/drive/MyDrive/Meta Data/'+str(year)+'/'+forders[i]
          # 검증 데이터셋인 202107은 제외시키자
          if forders[i]=='202107_uv.csv':
            continue
          df= pd.read_csv(file,encoding='utf-8')
          df_all = pd.concat([df_all, df],ignore_index=True)
  year+=1

# test 데이터 가져오기
df = pd.read_csv('/content/drive/MyDrive/Meta Data/2021/202107_uv.csv')

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ### 칼럼 선택하기
# - uv와의 correlation 을 따져보았을 때 corr의 절댓값이 소수점 둘째자리에서 반올림 했을 때 0.4 이상인 값들

# %%
# band3,band5,band8,band9,band10,band11,'band12','band13','band14','band15','band16',sateza 제외
scale_cols = ['band1', 'band2','band4','band6','band7','solarza','esr'] # 0.4 이상

# %% [markdown]
# ### 데이터 정규화
# * 정규화된 train 데이터는 df_scaled에 저장
# * 정규화된 test 데이터는 df_scaled_test에 저장

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %% [markdown]
# ### 3차원으로 재구성하기
# * 재구성된 train 데이터는 X_train_t
# * 재구성된 test 데이터는 X_test_t
#
# * 예측해야할 train 데이터는 y_train
# * 예측해야할 test 데이터는 y_test

# %% [markdown]
# # stn 별로 모델 학습시키기
# - stn 별 prediction 값을 배열에 넣어주기
# - stn 별 모델 성능 평가하기

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
from sklearn.metrics import confusion_matrix

# stn 값들
stn_index = [13,105,108,112,115,131,132]

# stn 별 예측한 값을 담을 배열
prediction = []
TP = []

# 오차범위
DIFF = 0.2

# stn 별 
for i in stn_index:
  # 학습 데이터 정규화
  df_scaled = scaler.fit_transform(df_all[df_all['stn']==i][scale_cols])
  df_scaled = pd.DataFrame(df_scaled)
  df_scaled.columns = scale_cols

  # 테스트 데이터 정규화
  df_scaled_test = scaler.fit_transform(df[df['stn']==i][scale_cols])
  df_scaled_test = pd.DataFrame(df_scaled_test)
  df_scaled_test.columns = scale_cols

  # 3차원으로 재구성하기
  X_train = df_scaled.values
  X_train_t = X_train.reshape(X_train.shape[0], X_train.shape[1],1) # 데이터셋 수, 칼럼 수, 1

  X_test = df_scaled_test.values
  X_test_t = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

  y_train = df_all[df_all['stn']==i]['uv'].values
  y_test = df[df['stn']==i]['uv'].values

  # LSTM 아키텍처 (architecture)
  model = Sequential()
  model.add(LSTM(units = 50, input_shape=(len(scale_cols), 1),activation='relu')) 
  model.add(Dense(1)) # 마지막 output 값이 하나

  # 컴파일링
  model.compile(optimizer='adam', loss='mse')

  # training data 세트에 피팅하기
  early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)
  model.fit(X_train_t, y_train, epochs = 10, batch_size = 120, verbose = 1, callbacks=[early_stop])

  #X_test_t를 LSTM 모델에 넣어서 예측하기
  y_pred = model.predict(X_test_t)

  #uv 값이 0보다 작은 건 0으로 바꾸기
  for i in range(len(y_pred)):
    if y_pred[i][0]<0:
      y_pred[i][0] = 0
  
  # 예측 배열에 넣어주기
  prediction.append(y_pred)

  # 모델 성능 평가하기
  predict_value = pd.DataFrame(y_pred)
  real_value = pd.DataFrame(y_test)
  result = pd.concat([real_value, predict_value],axis = 1)
  result.columns = ['real','predict']
  count = 0
  for i in range(len(result)):
    if abs(result['real'][i] - result['predict'][i]) <= DIFF:
      count+=1
  TP.append(round(count/len(result),3))
# Out:
# Epoch 1/10
# 831/831 [==============================] - 7s 7ms/step - loss: 2.1276
# Epoch 2/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.4414
# Epoch 3/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3788
# Epoch 4/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3539
# Epoch 5/10
# 831/831 [==============================] - 5s 6ms/step - loss: 0.3398
# Epoch 6/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.3298
# Epoch 7/10
# 831/831 [==============================] - 5s 6ms/step - loss: 0.3238
# Epoch 8/10
# 831/831 [==============================] - 5s 6ms/step - loss: 0.3223
# Epoch 9/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3170
# Epoch 10/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.3151
# Epoch 1/10
# 831/831 [==============================] - 7s 7ms/step - loss: 2.0973
# Epoch 2/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.6356
# Epoch 3/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3604
# Epoch 4/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3394
# Epoch 5/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3264
# Epoch 6/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3170
# Epoch 7/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.3145
# Epoch 8/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3096
# Epoch 9/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3070
# Epoch 10/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3066
# Epoch 1/10
# 831/831 [==============================] - 7s 7ms/step - loss: 1.0757
# Epoch 2/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2030
# Epoch 3/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.1779
# Epoch 4/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.1718
# Epoch 5/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.1653
# Epoch 6/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.1609
# Epoch 7/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.1586
# Epoch 8/10
# 831/831 [==============================] - 5s 6ms/step - loss: 0.1564
# Epoch 9/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.1523
# Epoch 10/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.1467
# Epoch 1/10
# 831/831 [==============================] - 7s 7ms/step - loss: 1.7579
# Epoch 2/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.3086
# Epoch 3/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2713
# Epoch 4/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2474
# Epoch 5/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2391
# Epoch 6/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.2370
# Epoch 7/10
# 831/831 [==============================] - 5s 6ms/step - loss: 0.2250
# Epoch 8/10
# 831/831 [==============================] - 5s 7ms/step - loss: 0.2256
# Epoch 8: early stopping
# Epoch 1/10
# 831/831 [==============================] - 7s 7ms/step - loss: 1.7537
# Epoch 2/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3058
# Epoch 3/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2864
# Epoch 4/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2832
# Epoch 5/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2810
# Epoch 6/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2802
# Epoch 7/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2749
# Epoch 8/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2765
# Epoch 8: early stopping
# Epoch 1/10
# 831/831 [==============================] - 7s 7ms/step - loss: 1.8322
# Epoch 2/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3274
# Epoch 3/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2763
# Epoch 4/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2687
# Epoch 5/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2619
# Epoch 6/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2590
# Epoch 7/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2509
# Epoch 8/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2506
# Epoch 9/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2513
# Epoch 9: early stopping
# Epoch 1/10
# 831/831 [==============================] - 7s 7ms/step - loss: 2.0528
# Epoch 2/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3325
# Epoch 3/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3101
# Epoch 4/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.3019
# Epoch 5/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2956
# Epoch 6/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2951
# Epoch 7/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2895
# Epoch 8/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2880
# Epoch 9/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2810
# Epoch 10/10
# 831/831 [==============================] - 6s 7ms/step - loss: 0.2786

# %%
for i in range(len(TP)) :
  print('stn 값 ',stn_index[i],': ',TP[i])
# Out:
# stn 값  13 :  0.527
# stn 값  105 :  0.507
# stn 값  108 :  0.517
# stn 값  112 :  0.52
# stn 값  115 :  0.532
# stn 값  131 :  0.505
# stn 값  132 :  0.497
